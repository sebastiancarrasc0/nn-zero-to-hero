# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 + 2*x + 4

# %%
f(3)
# Out:
# 37

# %%
xs = np.linspace(-10, 10, 100)
ys = f(xs)

# %%
plt.plot(xs,ys)

# %%
h = 0.0001
x = -5.0
(f(x) - f(x + h))/h
# Out:
# 27.999699999838867
